# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = sns.load_dataset('tips')

# %%
ds.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(ds['total_bill'], kde=True, bins=50) # we can use both displot and histplot 
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=ds, kind='resid')
plt.show()
# kind='scatter'
# kind='kde'
# kind='hist'
# kind='hex'
# kind='reg'
# kind='resid'

# %%
sns.pairplot(ds)
plt.show()

# %%
sns.pairplot(ds, hue='smoker')
plt.show()

# %%
sns.rugplot(ds['tip'])
plt.show()

# %%
sns.kdeplot(ds['total_bill'], fill=True)
# sns.rugplot(ds['total_bill'])
plt.show()

# %%
ds.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# sns.barplot(x='category', y='number', data=df)
# estimator = np.mean , np.median , np.sum , np.min , np.max , len
sns.barplot(x='day', y='tip', data=ds, estimator=len)
plt.show()

# %% [markdown]
# Middle line → median total bill
#
# Box → middle 50% of bills (Q1 to Q3)
#
# Whiskers → normal range
#
# Dots → outliers (very high/low bills)

# %%
sns.boxplot(x='day', y='total_bill', data= ds, hue='smoker')
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', data= ds, hue='smoker', split=True)
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data= ds, hue='sex', dodge= True)
plt.show()

# %%
sns.swarmplot(x='day', y='total_bill', data= ds)
plt.show()

# %%
# sns.catplot(x='day', y='total_bill', data= ds, kind='bar')
sns.catplot(x='day', y='total_bill', data= ds, kind='violin')
plt.show()

# %%
data_correlation = ds.corr(numeric_only=True)
print(data_correlation)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data_correlation, annot=True, cmap='coolwarm')
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.pivot_table(index='month',columns='year', values='passengers')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21968\3690281707.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(index='month',columns='year', values='passengers')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
flights_data = flights.pivot_table(index='month',columns='year', values='passengers')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21968\1268305780.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights_data = flights.pivot_table(index='month',columns='year', values='passengers')

# %%
sns.heatmap(flights_data, cmap='plasma', linewidth=0.5, linecolor='white') # cmap is the color mapping argument and annot is the annotation argument where the numbers are displayed and linewidth is the width of the lines and linecolor is the color of the lines
plt.show()

# %%
sns.clustermap(flights_data, cmap='plasma')
plt.show()

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df)
plt.show()

# %%
# so by using pairgrid we have various graphs
g = sns.PairGrid(df)
g.map_diag(sns.histplot) #map diagonal means the diagnoal plots of the pairplot 
g.map_lower(sns.scatterplot) #map lower means the lower plots
g.map_upper(sns.kdeplot) #map upper means the upper plots
plt.show()

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.FacetGrid(df, col='time', row='smoker') # this will give us an empty grid
plt.show()

# %%
#we can plot by doing the following
g = sns.FacetGrid(df, col='time', row='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip') # this will give us a scatter plot
plt.show()

# %%
g = sns.FacetGrid(df, col='time', row='smoker')
g.map(sns.histplot, 'total_bill',kde=True)
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips) # this will give us a scatter plot with a regression line
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex
plt.show()

# %%
#we can also do some stylling by doing the following
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex', palette='coolwarm', markers=['o','v']) # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and color mapping
plt.show()

# %%
# what seaborn is doing is calling matplotlib.pyplot under the hood to plot the regression line
# this gives us some more customization
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex', palette='coolwarm', markers=['o','v'], scatter_kws={'s':100}) # kws is the keyword arguments and scatter_kws is the keyword arguments for the scatter plot which is the size of the points
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, col='sex') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, row='sex', col='time') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex
plt.show()

# %%
#we can also do this 
sns.lmplot(x='total_bill',y='tip',data=tips, col='sex', row='time', hue='smoker') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and time
plt.show()

# %%
# so we can modify the plot
sns.lmplot(data=tips, x='total_bill',y='tip', hue='smoker', col='day') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and time
plt.show()

# %%
# its giving us 4 plots in one line so we can change the aspect of the plot
sns.lmplot(data=tips, x='total_bill',y='tip', hue='smoker', col='day', aspect=0.6)
plt.show()

# %%
sns.set_style("whitegrid") #this will change the style of the plot
# you can also add the following as argument
# sns.set_style("ticks")
# sns.set_style("dark")
# sns.set_style("darkgrid")
# sns.set_style("white")
# sns.set_style("whitegrid")
sns.countplot(data=tips, x = "smoker")   
plt.show()

# %%
sns.countplot(data=tips, x = "smoker")   
sns.despine() # this will remove the spines from the plot
# you can also add the following as argument
# sns.despine(left=True)
# sns.despine(bottom=True)
plt.show()

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
plt.show()

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',aspect=4,data=tips)
plt.show()

# %%
sns.set_context('poster',font_scale=1)
sns.countplot(x='sex',data=tips,palette='coolwarm')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21968\943407529.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')
